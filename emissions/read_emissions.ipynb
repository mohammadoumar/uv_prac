# %%
import pandas as pd

# %%
df = pd.read_csv("emissions.csv")

# %%
df
# Out:
#              timestamp project_name                                run_id  \
# 0  2026-03-05T20:53:01  uvmoondream  c355b3c1-cc7e-4568-be27-0785d3c1b385
#
#                           experiment_id   duration  emissions  emissions_rate  \
# 0  5b0fa12a-3dd7-45bb-9766-cc326314d9f1  21.144051   0.000035        0.000002
#
#    cpu_power  gpu_power  ram_power  ...  latitude  ram_total_size  \
# 0   28.01073  90.834877       20.0  ...     48.11              64
#
#    tracking_mode  cpu_utilization_percent  gpu_utilization_percent  \
# 0        machine                 0.794737                     20.0
#
#   ram_utilization_percent ram_used_gb on_cloud  pue  wue
# 0                4.863158    48.95742        N  1.0  0.0
#
# [1 rows x 38 columns]

# %%
df.columns
# Out:
# Index(['timestamp', 'project_name', 'run_id', 'experiment_id', 'duration',
#        'emissions', 'emissions_rate', 'cpu_power', 'gpu_power', 'ram_power',
#        'cpu_energy', 'gpu_energy', 'ram_energy', 'energy_consumed',
#        'water_consumed', 'country_name', 'country_iso_code', 'region',
#        'cloud_provider', 'cloud_region', 'os', 'python_version',
#        'codecarbon_version', 'cpu_count', 'cpu_model', 'gpu_count',
#        'gpu_model', 'longitude', 'latitude', 'ram_total_size', 'tracking_mode',
#        'cpu_utilization_percent', 'gpu_utilization_percent',
#        'ram_utilization_percent', 'ram_used_gb', 'on_cloud', 'pue', 'wue'],
#       dtype='object')

# %%
df.iloc[0]
# Out:
# timestamp                                         2026-03-05T20:53:01
# project_name                                              uvmoondream
# run_id                           c355b3c1-cc7e-4568-be27-0785d3c1b385
# experiment_id                    5b0fa12a-3dd7-45bb-9766-cc326314d9f1
# duration                                                    21.144051
# emissions                                                    0.000035
# emissions_rate                                               0.000002
# cpu_power                                                    28.01073
# gpu_power                                                   90.834877
# ram_power                                                        20.0
# cpu_energy                                                   0.000157
# gpu_energy                                                   0.000354
# ram_energy                                                   0.000112
# ...
